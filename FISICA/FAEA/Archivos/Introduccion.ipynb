# %%
import ROOT as rt

# %% [markdown]
# # Probar cositas

# %%
f = rt.TFile("../Datos/ttbar.root")
t = f.Get("events")  # Obtener el árbol directamente


canvas = rt.TCanvas("canvas", "NJet Distribution", 800, 600)
t.Draw("NJet")
canvas.Draw()
# Out:
# <div id="root_plot_1773092039869" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1773092039869(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1.37500010244549,"fY1":-1303.18134709458,"fX2":12.3750001024455,"fY2":11728.6313470946,"fXtoAbsPixelk":79.6000047445299,"fXtoPixelk":79.6000047445299,"fXtoPixel":57.8909082282673,"fYtoAbsPixelk":514.799996590614,"fYtoPixelk":514.799996590614,"fYtoPixel":-0.0438925891142568,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-1.37500010244549,"fPixeltoXk":-1.37500010244549,"fPixeltoX":0.0172738696041344,"fAbsPixeltoYk":11728.6313470946,"fPixeltoYk":-1303.18134709458,"fPixeltoY":-22.7828893255055,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":11,"fUymax":10425.45,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"canvas","fTitle":"NJet Distribution","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,25 ...

# %% [markdown]
# # Ejercicio

# %%
v1 = rt.TLorentzVector()
v1.SetPxPyPzE(10.0,10.0,10.0,35.0)

v2 = rt.TLorentzVector()
v2.SetPxPyPzE(20.0,20.0,20.0,42.0)

v3 = v1 + v2

print ("Momento trasverso de v3: ", v3.Pt())
print ("Las componentes de v3 son: \n", "Px=", v3.Px(), "\n Py=", v3.Py(), "\n Pz=", v3.Pz(), "\n E=", v3.E())
print ("La masa de v3 es: ", v3.M())
print ("Angulo polar de v3: ", v3.Theta())
print ("La pseudorapidez de v3 es: ", v3.Eta())
# Out:
# Momento trasverso de v3:  42.42640687119285
# Las componentes de v3 son:
#  Px= 30.0
#  Py= 30.0
#  Pz= 30.0
#  E= 77.0
# La masa de v3 es:  56.824290580701486
# Angulo polar de v3:  0.9553166181245093
# La pseudorapidez de v3 es:  0.6584789484624083

# %%
new_canvas = rt.TCanvas("new_canvas", "Canvas de histograma", 800, 600)
h = rt.TH1F("EFPT0", "Energía Faltante plano trasverso", 30, 0, 400)
h.SetXTitle("MET (GeV)")
h.SetYTitle("cantidad de eventos")
h.SetLineColor(rt.kBlue)
h.SetLineWidth(2)
h.SetFillColor(rt.kBlue-10)
legend = rt.TLegend(0.48,0.9,0.1,0.8) # x1,y1,x2,y2
legend.SetHeader("Legend","C")

legend.AddEntry(h,"Histograma para 0 muones","l")

t.Draw("sqrt(MET_px*MET_px + MET_py*MET_py)>>EFPT0","NMuon < 1","same")

legend.Draw()

new_canvas.Draw("same")
# Out:
# <div id="root_plot_1773092040389" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1773092040389(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-50.0000037252905,"fY1":-974.662572618019,"fX2":450.000003725291,"fY2":8771.96257261802,"fXtoAbsPixelk":79.6000047445299,"fXtoPixelk":79.6000047445299,"fXtoPixel":1.59199997627735,"fYtoAbsPixelk":514.799996590614,"fYtoPixelk":514.799996590614,"fYtoPixel":-0.0586869805164901,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-50.0000037252905,"fPixeltoXk":-50.0000037252905,"fPixeltoX":0.628140712877614,"fAbsPixeltoYk":8771.96257261802,"fPixeltoYk":-974.662572618019,"fPixeltoY":-17.0395544497134,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":400,"fUymax":7797.3,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"new_canvas","fTitle":"Canvas de histograma","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24, ...

# %%
new_canvas = rt.TCanvas("new_canvas", "Canvas de histograma", 800, 600)
h2 = rt.TH1F("EFPT1", "Energía Faltante plano trasverso", 30, 0, 400)
h2.SetXTitle("MET (GeV)")
h2.SetYTitle("cantidad de eventos")
h2.SetLineColor(rt.kRed)
h2.SetLineWidth(2)
h2.SetFillColor(rt.kRed-10)


legend = rt.TLegend(0.48,0.9,0.1,0.8) # x1,y1,x2,y2
legend.SetHeader("Legend","C")
legend.AddEntry(h2,"Histograma para 1 muones","l")

t.Draw("sqrt(MET_px*MET_px + MET_py*MET_py)>>EFPT1","NMuon > 0","same")

legend.Draw("same")

new_canvas.Draw("same")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: new_canvas
# <div id="root_plot_1773092040541" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1773092040541(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-50.0000037252905,"fY1":-130.856259749551,"fX2":450.000003725291,"fY2":1177.70625974955,"fXtoAbsPixelk":79.6000047445299,"fXtoPixelk":79.6000047445299,"fXtoPixel":1.59199997627735,"fYtoAbsPixelk":514.799996590614,"fYtoPixelk":514.799996590614,"fYtoPixel":-0.437120879955322,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-50.0000037252905,"fPixeltoXk":-50.0000037252905,"fPixeltoX":0.628140712877614,"fAbsPixeltoYk":1177.70625974955,"fPixeltoYk":-130.856259749551,"fPixeltoY":-2.28769671241102,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":400,"fUymax":1046.85,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"new_canvas","fTitle":"Canvas de histograma","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24, ...

# %%
# Crear un lienzo (canvas) de 800x600 píxeles para dibujar los histogramas
new_canvas = rt.TCanvas("new_canvas", "Canvas de histograma", 800, 600)

# Crear primer histograma (h) para eventos con 0 muones
# 30 bins, rango de 0 a 400 GeV
h = rt.TH1F("EFPT0", "Energía Faltante plano trasverso", 30, 0, 400)
h.SetXTitle("MET (GeV)")  # Etiqueta del eje X
h.SetYTitle("cantidad de eventos")  # Etiqueta del eje Y
h.SetLineColor(rt.kBlue)  # Color de línea azul
h.SetLineWidth(2)  # Grosor de línea

h.SetStats(0)  # Ocultar estadísticas
# Crear leyenda en posición (0.6,0.9) a (0.9,0.8)
legend = rt.TLegend(0.6,0.9,0.9,0.8)  # x1,y1,x2,y2
legend.SetHeader("Legend","C")
legend.AddEntry(h,"Histograma para 0 muones","l")

# Crear segundo histograma (h2) para eventos con 1+ muones
h2 = rt.TH1F("EFPT1", "Energia Faltante plano trasverso", 30, 0, 400)
h2.SetXTitle("MET (GeV)")
h2.SetYTitle("cantidad de eventos")
h2.SetLineColor(rt.kRed)  # Color de línea rojo
h2.SetLineWidth(2)

# Añadir h2 a la leyenda
legend.SetHeader("Legend","C")
legend.AddEntry(h2,"Histograma para 1 muones","l")

# Llenar los histogramas desde el árbol (t)
# MET = raíz cuadrada de (px² + py²)
# "goff" = no mostrar (solo rellenar)
t.Draw("sqrt(MET_px*MET_px + MET_py*MET_py)>>EFPT0","NMuon < 1","goff")  # h: solo eventos con 0 muones
t.Draw("sqrt(MET_px*MET_px + MET_py*MET_py)>>EFPT1","NMuon > 0","goff")  # h2: eventos con 1+ muones

# Normalizar ambos histogramas dividiendo por su integral (área total)
# Esto permite comparar formas con diferentes números de eventos
h.Scale(1.0/h.Integral())
h2.Scale(1.0/h2.Integral())

# Dibujar h como histograma de barras
h.Draw("hist")
# Superponer h2 en el mismo gráfico
h2.Draw("hist same")

# Mostrar la leyenda
legend.Draw()

# Mostrar el lienzo y guardar como imagen
new_canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: new_canvas
# Warning in <TFile::Append>: Replacing existing TH1: EFPT0 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: EFPT1 (Potential memory leak).
# Info in <TCanvas::Print>: png file histograma_comparativo.png has been created
# <div id="root_plot_1773092040797" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1773092040797(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-50.0000037252905,"fY1":-0.0315905287184215,"fX2":450.000003725291,"fY2":0.284314739636371,"fXtoAbsPixelk":79.6000047445299,"fXtoPixelk":79.6000047445299,"fXtoPixel":1.59199997627735,"fYtoAbsPixelk":514.799996590614,"fYtoPixelk":514.799996590614,"fYtoPixel":-1810.66939142524,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-50.0000037252905,"fPixeltoXk":-50.0000037252905,"fPixeltoX":0.628140712877614,"fAbsPixeltoYk":0.284314739636371,"fPixeltoYk":-0.0315905287184215,"fPixeltoY":-5.52281937683204e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":400,"fUymax":0.25272421091795,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"new_canvas","fTitle":"Canvas de histograma","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:1 ...

# %%
new_canvas.Print("histograma_comparativo.png")  # Exportar a PNG

# %%
# ========================================
# PARTE 1: CARGAR DATOS DE SIMULACIÓN DY
# ========================================
dy = rt.TFile("../Datos/dy.root")
t = dy.Get("events")  # Obtener el árbol de eventos de la simulación Drell-Yan

# Crear canvas dividido en 4 pads (2x2)
canvas = rt.TCanvas("canvas", "Análisis DY vs Datos", 1600, 1000)
canvas.Divide(2,2)  # 2 columnas, 2 filas

# ========================================
# HISTOGRAMA 1: MET para DY (h)
# ========================================
h = rt.TH1F("EFPT0", "Energía Faltante plano trasverso", 30, 0, 80)
h.SetXTitle("MET (GeV)")
h.SetYTitle("cantidad de eventos")
h.SetLineColor(rt.kBlue)  # Color azul para DY
h.SetLineWidth(2)
h.SetStats(0)  # Ocultar cuadro de estadísticas

# ========================================
# HISTOGRAMA 2: Masa invariante para DY (h_masa)
# ========================================
h_masa = rt.TH1F("masa", "Masa invariante di-muon", 30, 0, 140)
h_masa.SetXTitle("M (GeV)")
h_masa.SetYTitle("cantidad de eventos")
h_masa.SetLineColor(rt.kGreen)  # Color verde para DY
h_masa.SetLineWidth(2)
h_masa.SetStats(0)

# Llenar histograma de MET para eventos con 2 muones
t.Draw("sqrt(MET_px*MET_px + MET_py*MET_py)>>EFPT0","NMuon == 2","goff")

# Calcular masa invariante di-muon para eventos DY
for entry in t:
    if entry.NMuon == 2:  # Solo eventos con exactamente 2 muones
        # Crear vectores 4-momento para cada muón
        Muon1 = rt.TLorentzVector()
        Muon1.SetPxPyPzE(entry.Muon_Px[0], entry.Muon_Py[0], entry.Muon_Pz[0], entry.Muon_E[0])
        Muon2 = rt.TLorentzVector()
        Muon2.SetPxPyPzE(entry.Muon_Px[1], entry.Muon_Py[1], entry.Muon_Pz[1], entry.Muon_E[1])
        # Sumar vectores para obtener el sistema di-muon
        diMuon = Muon1 + Muon2
        h_masa.Fill(diMuon.M())  # Llenar con la masa invariante


# ========================================
# PARTE 2: CARGAR DATOS EXPERIMENTALES
# ========================================
data = rt.TFile("../Datos/data.root")
t = data.Get("events")  # Obtener el árbol de datos experimentales

# ========================================
# HISTOGRAMA 3: MET para Datos (h2)
# ========================================
h2 = rt.TH1F("EFPT1", "Energía Faltante plano trasverso", 30, 0, 80)
h2.SetXTitle("MET (GeV)")
h2.SetYTitle("cantidad de eventos")
h2.SetLineColor(rt.kRed)  # Color rojo para datos
h2.SetLineWidth(2)
h2.SetStats(0)
t.Draw("sqrt(MET_px*MET_px + MET_py*MET_py)>>EFPT1","NMuon == 2","goff")

# ========================================
# HISTOGRAMA 4: Masa invariante para Datos (h_masa2)
# ========================================
h_masa2 = rt.TH1F("masa2", "Masa invariante 2 muones", 30, 0, 140)
h_masa2.SetXTitle("M (GeV)")
h_masa2.SetYTitle("cantidad de eventos")
h_masa2.SetLineColor(rt.kMagenta)  # Color magenta para datos
h_masa2.SetLineWidth(2)
h_masa2.SetStats(0)

# Calcular masa invariante di-muon para datos experimentales
for entry in t:
    if entry.NMuon == 2:
        Muon1 = rt.TLorentzVector()
        Muon1.SetPxPyPzE(entry.Muon_Px[0], entry.Muon_Py[0], entry.Muon_Pz[0], entry.Muon_E[0])
        Muon2 = rt.TLorentzVector()
        Muon2.SetPxPyPzE(entry.Muon_Px[1], entry.Muon_Py[1], entry.Muon_Pz[1], entry.Muon_E[1])
        diMuon = Muon1 + Muon2
        h_masa2.Fill(diMuon.M())


# ========================================
# NORMALIZACIÓN DE HISTOGRAMAS
# ========================================
# Crear leyenda para histogramas de MET
legend = rt.TLegend(0.6,0.9,0.9,0.75) # x1,y1,x2,y2
legend.SetHeader("Legend","C")
legend.AddEntry(h,"Histograma para DY","l")
legend.AddEntry(h2,"Histograma para datos","l")

# Normalizar histogramas de MET (dividir por integral para comparar formas)
h.Scale(1.0/h.Integral())
print("Integral de h2: ", h2.Integral())
h2.Scale(1.0/h2.Integral())

# ========================================
# PAD 1: Comparación de MET (DY vs Datos)
# ========================================
canvas.cd(1)  # Activar primer pad
h.Draw("hist")  # Dibujar DY
h2.Draw("hist same")  # Superponer Datos
legend.Draw()

# ========================================
# PAD 2: Ratio de MET (Datos/DY)
# ========================================
canvas.cd(2)  # Activar segundo pad
h_ratio_met = h2.Clone("h_ratio_met")  # Clonar histograma de datos
h_ratio_met.Divide(h)  # Dividir bin por bin: Datos/DY
h_ratio_met.SetTitle("Ratio MET (Datos/DY)")
h_ratio_met.SetYTitle("Datos/DY")
h_ratio_met.SetLineColor(rt.kBlack)
h_ratio_met.SetMarkerStyle(20)  # Marcadores circulares
h_ratio_met.SetMarkerSize(0.8)
h_ratio_met.Draw("E")  # Dibujar con barras de error
# Línea de referencia en y=1 (indica acuerdo perfecto)
line_met = rt.TLine(0, 1, 80, 1)
line_met.SetLineColor(rt.kRed)
line_met.SetLineStyle(2)  # Línea punteada
line_met.Draw("same")

# ========================================
# PAD 3: Comparación de Masa Invariante (DY vs Datos)
# ========================================
# Crear leyenda para histogramas de masa
legend2 = rt.TLegend(0.7,0.9,0.9,0.75) # x1,y1,x2,y2
legend2.SetHeader("Legend","C")
legend2.AddEntry(h_masa,"Masa invariante para DY","l")
legend2.AddEntry(h_masa2,"Masa invariante para datos","l")

# Normalizar histogramas de masa invariante
h_masa.Scale(1.0/h_masa.Integral())
h_masa2.Scale(1.0/h_masa2.Integral())

canvas.cd(3)  # Activar tercer pad
h_masa.Draw("hist")  # Dibujar DY
h_masa2.Draw("hist same")  # Superponer Datos
legend2.Draw()

# ========================================
# PAD 4: Ratio de Masa Invariante (Datos/DY)
# ========================================
canvas.cd(4)  # Activar cuarto pad
h_ratio_masa = h_masa2.Clone("h_ratio_masa")  # Clonar histograma de datos
h_ratio_masa.Divide(h_masa)  # Dividir bin por bin: Datos/DY
h_ratio_masa.SetTitle("Ratio Masa Invariante (Datos/DY)")
h_ratio_masa.SetYTitle("Datos/DY")
h_ratio_masa.SetLineColor(rt.kBlack)
h_ratio_masa.SetMarkerStyle(20)
h_ratio_masa.SetMarkerSize(0.8)
h_ratio_masa.Draw("E")  # Dibujar con barras de error (propagación estadística)
# Línea de referencia en y=1
line_masa = rt.TLine(0, 1, 140, 1)
line_masa.SetLineColor(rt.kRed)
line_masa.SetLineStyle(2)
line_masa.Draw("same")

# Mostrar el canvas completo
canvas.Draw()
# Out:
# Integral de h2:  18682.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# <div id="root_plot_1773092051319" style="width: 1600px; height: 1000px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1773092051319(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":0,"fXtoPixelk":0,"fXtoPixel":1596,"fYtoAbsPixelk":972,"fYtoPixelk":972,"fYtoPixel":-972,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":1596,"fVtoAbsPixelk":972,"fVtoPixelk":972,"fVtoPixel":-972,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":6.265664160401e-4,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00102880658436214,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"canvas","fTitle":"An\u00e1lisis DY vs Datos","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":12.5,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":1596,"fCh":972,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fClassName":"","fObjectName":"","fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:201,31,22;112:200,73,169;113:173,173,125;114:134,200,221;115:87,141,255;116:101,99,100;117:63,144,218;118:255,169,14;119:189,31,1;120:148,164,162;121:131,45,182;122:169,107,89;123:231 ...

# %%
canvas.Print("comparacion_dy_datos.png")
# Out:
# Info in <TCanvas::Print>: png file comparacion_dy_datos.png has been created
