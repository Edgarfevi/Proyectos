# %% [markdown]
# # Landa vs n

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Codigo

# %%
def n(theta,A=45): #n(lambda)
    theta = np.radians(theta)
    A = np.radians(A)
    
    return np.sin((A + theta)/2) / np.sin(A/2)
## Hg
theta = [91.10-110,90.50-110,90.43-110,90.5-110,90.39-110]
color = ['purple','green','orange','yellow','red']
# Verde lima
def nEdgar(theta,A=30):
    
    theta = np.radians(theta)
    return np.sin(theta)/np.sin(np.deg2rad(-13)) #n(lambda)


plt.figure(figsize=(8,6))
for i in range(len(theta)):
    plt.plot(theta[i], nEdgar(theta[i]), 'o', color=color[i])
    plt.xlabel('theta (°)')
    plt.ylabel('n(lambda)')
    plt.title('Refractive index vs angle of incidence')
    plt.grid()
    print(f'Para {color[i]}: n = {nEdgar(theta[i]):.4f}')
plt.show()
# Out:
# Para purple: n = 1.4399
# Para green: n = 1.4839
# Para orange: n = 1.4890
# Para yellow: n = 1.4839
# Para red: n = 1.4920

# %%
theta = [91.10,91.00, 90.6,90.40 ]
color = ['purple','blue','green','lime']
# Azul claro
# verde oscuro
# verde lima el segundo verde
plt.figure(figsize=(8,6))
for i in range(len(theta)):
    plt.plot(theta[i], n(theta[i]), 'o', color=color[i]) 
    print(f'Para {color[i]}: n = {n(theta[i]):.4f}')
plt.show()
# Out:
# Para purple: n = 2.4237
# Para blue: n = 2.4228
# Para green: n = 2.4194
# Para lime: n = 2.4177
